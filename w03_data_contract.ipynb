# %% [markdown]
# <a href="https://colab.research.google.com/github/kushagraverma545/flyrank-internship-ml/blob/main/w03_data_contract.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-04 — Search Intelligence Data Contract
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w03_data_contract.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. Unit of analysis + time window
#
# *One row = one what, over which dates? State it, then verify it below.*

# %% [markdown]
# For a Google Search console dataset,a good answer is:
#
# Unit of analysis:One row represents one search query on one date(or one query-page-date combination,de[pending onyour dataset).
#
# Time-window:Data covers the selected Google Serch Console export period(for ex,last 90 dayss)

# %%
import pandas as pd
import numpy as np
df=pd.read_csv

df.shape
df['Date'].min()
df['Date'].max()

df['Date'].nunique()

# %% [markdown]
# ## 2. Fields: feature / label / context / excluded
#
# *Sort every field you plan to touch into these four buckets. Excluded needs a why.*

# %% [markdown]
# For Ranking Signal Analysis:
#
# Features:
#
# *Clicks
# *Impressions
# *CTR
#
# Label:
#
# *Average position
#
# Context
#
# *Device
# *Country
# *Query
# *Date
#
# Excluded
#
# Examples:
#
# *Search Appearence
# *Page
#
# Reason:
# Excluded because they are outside the scope of this research question or contain too many missing values.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Verify it with queries (grain, counts, missing values, windows)
#
# *Every claim above gets a query cell here. A contract claim without a query next to it is a guess.*

# %% [markdown]
# Every statement must be supported by code.

# %%
import pandas as pd
import numpy as np
df=pd.read_csv

df.isnull().sum()     #Count missing values
df.dtypes      #Check Data types
df['Device'].value_counts()    #Number of devices
df['Country'].value_counts().head(10)    # Number of countries
df['Average Positions'].describe()    #Position statistics
df[['Clicks','Impressions','CTR','Average Position']].corr() #Correlation

# %% [markdown]
# ## 4. Data limits
#
# *What can this data never tell you? Unbalanced history, GSC-only early rows, window overlaps.*

# %% [markdown]
# *Data comes only from Google Search Console.
# *It cannot  explain why rankings changed.
# *Correlation does not imply causation.
# *Historical data is limited to the exported time period.
# *Some queries may have very few impressions,making results noisy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
